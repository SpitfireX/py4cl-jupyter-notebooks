# %% [markdown]
# # Lemmatisierung mit regulären Ausdrücken ... zumindest fast
# In dieser Übung geht es darum, die Flexionsaffixe von Verben zu entfernen. Dies ist ein erster Schritt zur Lemmatisierung, also dazu, konkrete Wortformen auf ihre Zitierformen im Lexikon zurückzuführen. Wir werden dabei sehen, dass es mit diesem Schritt oft nicht getan ist, dass ordentliche Lemmatisierung also noch ein gutes Stück schwieriger ist.

# %% [markdown]
# ## Nötige Pakete importieren
# Um eine TSV-Datei zu öffnen, verwenden wir hier *pandas*, weil wir damit leichter auf einzelne Tabellenspalten zuzugreifen. Achtung, Pandas ist nicht Teil der Standardbibliothek und muss separat installiert werden. Das sollte in den meisten Python3-Umgebungen über den Python-eigenen Paketmanager `pip3` möglich sein. Um Pandas zu installieren, muss nur der Befehl `pip3 install --user pandas` in einem Terminal ausgeführt werden. (Wer eine Entwicklungsumgebung wie PyCharm nutzt, kann das ggf. auch über ein Menü dieser Umgebung erledigen.)
#
# Sollte die Installation von Pandas nicht möglich sein, kann die TSV-Datei auch über das `csv`-Modul der Standardbibliothek eingelesen werden. Eine Anleitung, wie das möglich ist, gibt es z. B. [hier](https://medium.com/@adds68/parsing-tsv-file-with-csv-in-python-662d6347b0cd).
#
# Außerdem brauchen wir natürlich reguläre Ausdrücke.

# %%
import pandas as pd
import re

# %% [markdown]
# ## Tabelle einlesen
# Die Datei "uebung_verben.tsv" enthält 500 Treffer aus einer Suche nach Vollverben im DWDS-Kernkorpus. (Die Abfrage sieht so aus: <https://www.dwds.de/r?q=%24p%3DVV*+%23sep&corpus=kern&date-start=1900&date-end=1999&genre=Belletristik&genre=Wissenschaft&genre=Gebrauchsliteratur&genre=Zeitung&format=full&sort=random&limit=10>)
#
# Neben den konkreten Wortformen, die von der Abfrage gefunden wurden, enthält die Datei auch für jede Form den kompletten Satz, in dem sie vorkommt, sowie Informationen zur Textquelle. Jede Information befindet sich in einer eigenen Spalte der Tabelle.
#
# Da Spalten in dieser Tabelle mit Tabstops (\t) getrennt sind, bietet sich read_table() an.

# %%
path = "uebung_verben.tsv"
table = pd.read_table(path)
table
# Out:
#           match                                           sentence collection  \
# 0      entsteht  Es bleibt wohl dem , der die Frage zu stellen ...       kern
# 1      verloren  Diese Sumpfreminiszenzen , die mich nicht herg...       kern
# 2    abschaffen  Hitler ist schon seit langen Monaten deutscher...       kern
# 3         hielt  Warum tat er es nicht , sondern hielt an sich ...       kern
# 4      bewahren  Er besitzt eigentlich alles , was eine Frau vo...       kern
# ..          ...                                                ...        ...
# 495       fälle  Und der Satz » ich fälle einen Baum « ist eben...       kern
# 496       lebte  Für mich war der Kreis bedeutsam durch eine st...       kern
# 497       wagte  Bald wagte ein Wärter , sich ihm und der Kiste...       kern
# 498     abbauen  Und wenn die Ausgaben hierfür und für die Wart...       kern
# 499    schaffen  Da man trotz öfteren gegenteiligen Versicherun...       kern
#
#                            author  \
# 0               Sloterdijk, Peter
# 1                       May, Karl
# 2    Kurt Tucholsky:Kaspar Hauser
# 3                   Huch, Ricarda
# 4                   Strauß, Botho
# ..                            ...
# 495               Mauthner, Fritz
# 496               Steiner, Rudolf
# 497             Morgner, Irmtraud
# 498                   Grimm, Hans
# 499                       unknown
#
#                                                  title  \
# 0                        Kritik der zynischen Vernunft
# 1                               Mein Leben und Streben
# 2                                    Hitler und Goethe
# 3                       Der große Krieg in Deutschland
# 4                                       Der junge Mann
# ..                                                 ...
# 495                         Wörterbuch der Philosophie
# 496                                    Mein Lebensgang
# 497  Leben und Abenteuer der Trobadora Beatriz nach...
# 498                                     Volk ohne Raum
# 499                                                NaN
#
#                                textClass  \
# 0                           Wissenschaft
# 1    Gebrauchsliteratur::Autobiographien
# 2                                Zeitung
# 3       Belletristik::Gebrauchsliteratur
# 4                    Belletristik::Roman
# ..                                   ...
# 495             Wissenschaft::Phiosophie
# 496  Gebrauchsliteratur::Autobiographien
# 497                         Belletristik
# 498                  Belletristik::Roman
# 499               Zeitung::Abend-Ausgabe
#
#                                                   bibl        date
# 0    Sloterdijk, Peter: Kritik der zynischen Vernun...  1983-12-31
# 1    May, Karl: Mein Leben und Streben, Selbstbiogr...  1910-12-31
# 2    Tucholsky, Kurt: Hitler und Goethe. In: Kurt T...  1932-05-17
# 3    Huch, Ricarda: Der Dreißigjährige Krieg, Wiesb...  1914-12-31
# 4    Strauß, Botho: Der junge Mann, München: Hanser...  1984-12-31
# ..                                                 ...         ...
# 495  Mauthner, Fritz: Wörterbuch der Philosophie. I...  1910-12-31
# 496  Steiner, Rudolf: Mein Lebensgang, Eine nicht v...  1925-04-05
# 497  Morgner, Irmtraud: Leben und Abenteuer der Tro...  1974-12-31
# 498  Grimm, Hans: Volk ohne Raum, München: Langen 1...  1926-12-31
# 499     Berliner Tageblatt (Abend-Ausgabe), 04.03.1916  1916-03-04
#
# [500 rows x 8 columns]

# %% [markdown]
# ## Verbformen

# %% [markdown]
# Wir brauchen hier eigentlich nur die erste Spalte ...

# %%
verben = table["match"]
verben
# Out:
# 0        entsteht
# 1        verloren
# 2      abschaffen
# 3           hielt
# 4        bewahren
#           ...
# 495         fälle
# 496         lebte
# 497         wagte
# 498       abbauen
# 499      schaffen
# Name: match, Length: 500, dtype: object

# %% [markdown]
# Das ist nun strenggenommen ein spezieller Objekttyp aus *pandas* (nämlich *Series*), aber wir können ganz normal damit arbeiten.
#
# Die Aufgabe besteht nun darin, den untenstehenden Code so anzupassen, dass bei jeder Verbform Flexionsaffixe entfernt werden.  Eine kurze Übersicht über Verbkonjugation im Deutschen gibt es z.B. bei Wikipedia: <https://de.wikipedia.org/wiki/Konjugation_(Grammatik)>
#
# Finde also einen passenden regulären Ausdruck!
#
# Welche Probleme treten dabei auf? Welche weiteren Schritte müssten für eine vollständige Lemmatisierung noch umgesetzt werden?

# %%
flektionsmuster = [
    r'(\w+[rl])n', # infinitiv
    r'(\w+)' # catch-all
]

def lemma(verb):
    for muster in flektionsmuster:
        match = re.fullmatch(muster, verb)
        if match:
            return ''.join(match.groups())

for verb in verben:
    print(f"{verb} -> {lemma(verb)}en")
# Out:
# entsteht -> entstehten
# verloren -> verlorenen
# abschaffen -> abschaffenen
# hielt -> hielten
# bewahren -> bewahrenen
# gesagt -> gesagten
# verkündet -> verkündeten
# krallte -> krallteen
# wohnt -> wohnten
# eingetroffen -> eingetroffenen
# zieht -> ziehten
# meldet -> meldeten
# hören -> hörenen
# erhob -> erhoben
# griff -> griffen
# stoben -> stobenen
# träumend -> träumenden
# geraucht -> gerauchten
# schwieg -> schwiegen
# notiert -> notierten
# geschminkt -> geschminkten
# betrifft -> betrifften
# gemacht -> gemachten
# führen -> führenen
# gekriegt -> gekriegten
# übergesetzt -> übergesetzten
# rief -> riefen
# ablegte -> ablegteen
# stimme -> stimmeen
# kommen -> kommenen
# anvertraut -> anvertrauten
# heiraten -> heiratenen
# begann -> begannen
# verfolgen -> verfolgenen
# konferierte -> konferierteen
# kostete -> kosteteen
# gesehen -> gesehenen
# erkennen -> erkennenen
# setzen -> setzenen
# gespuckt -> gespuckten
# polierten -> poliertenen
# erregt -> erregten
# darstellt -> darstellten
# versuchen -> versuchenen
# geißelte -> geißelteen
# gegründet -> gegründeten
# gab -> gaben
# kommt -> kommten
# voraussehen -> voraussehenen
# unterzeichnen -> unterzeichnenen
# gehangen -> gehangenen
# aufschrie -> aufschrieen
# angewachsen -> angewachsenen
# erwiderte -> erwiderteen
# verringern -> verringeren
# verlangen -> verlangenen
# paßte -> paßteen
# zugelassen -> zugelassenen
# erklären -> erklärenen
# verzichten -> verzichtenen
# reduziert -> reduzierten
# gibt -> gibten
# ausgezogen -> ausgezogenen
# merken -> merkenen
# gerührt -> gerührten
# gellt -> gellten
# behalten -> behaltenen
# verheißt -> verheißten
# wende -> wendeen
# weiß -> weißen
# wandeln -> wandelen
# bekundet -> bekundeten
# enthält -> enthälten
# einbringe -> einbringeen
# fordern -> forderen
# angeredet -> angeredeten
# lassen -> lassenen
# genommen -> genommenen
# siedelte -> siedelteen
# sagen -> sagenen
# verschwand -> verschwanden
# gerichtet -> gerichteten
# geführt -> geführten
# trennen -> trennenen
# nahm -> nahmen
# drehen -> drehenen
# wähle -> wähleen
# besucht -> besuchten
# abgeändert -> abgeänderten
# überreicht -> überreichten
# geben -> gebenen
# zusammengenommen -> zusammengenommenen
# aufwies -> aufwiesen
# arbeitet -> arbeiteten
# erörtern -> erörteren
# macht -> machten
# ging -> gingen
# folgt -> folgten
# sträubte -> sträubteen
# zeigt -> zeigten
# unterliegen -> unterliegenen
# bewegte -> bewegteen
# wirft -> wirften
# formuliert -> formulierten
# findet -> findeten
# ankommt -> ankommten
# zählt -> zählten
# sehen -> sehenen
# gestopft -> gestopften
# bearbeitet -> bearbeiteten
# auswirken -> auswirkenen
# abschnitten -> abschnittenen
# vollud -> volluden
# begegneten -> begegnetenen
# garantieren -> garantierenen
# fällt -> fällten
# verkündete -> verkündeteen
# gehen -> gehenen
# teilnimmt -> teilnimmten
# sieht -> siehten
# veröffentlichen -> veröffentlichenen
# vorbeigefahren -> vorbeigefahrenen
# hörte -> hörteen
# wirken -> wirkenen
# genannt -> genannten
# zurückkommen -> zurückkommenen
# erfolgt -> erfolgten
# umfaßte -> umfaßteen
# gestattet -> gestatteten
# aß -> aßen
# ausgeschlossen -> ausgeschlossenen
# diskutieren -> diskutierenen
# liefern -> lieferen
# verlassen -> verlassenen
# führt -> führten
# steigern -> steigeren
# aufgeführt -> aufgeführten
# schimpfen -> schimpfenen
# belastet -> belasteten
# wechselte -> wechselteen
# ziehen -> ziehenen
# regnete -> regneteen
# angekettet -> angeketteten
# gekommen -> gekommenen
# gelautet -> gelauteten
# bewilligt -> bewilligten
# abgegeben -> abgegebenen
# machte -> machteen
# gegenüberzusetzen -> gegenüberzusetzenen
# festzusetzen -> festzusetzenen
# paßt -> paßten
# angedeihen -> angedeihenen
# aufgefordert -> aufgeforderten
# meine -> meineen
# herbeiführen -> herbeiführenen
# gesehn -> gesehnen
# gepflückt -> gepflückten
# gewählt -> gewählten
# geholfen -> geholfenen
# gehört -> gehörten
# liegt -> liegten
# nennen -> nennenen
# geboren -> geborenen
# tagte -> tagteen
# durcheilt -> durcheilten
# überführen -> überführenen
# sitzen -> sitzenen
# gestorben -> gestorbenen
# ausschüttete -> ausschütteteen
# gesandt -> gesandten
# verhindert -> verhinderten
# folgte -> folgteen
# kämpfen -> kämpfenen
# brauchen -> brauchenen
# zeichnet -> zeichneten
# riechen -> riechenen
# gedachte -> gedachteen
# eingeht -> eingehten
# blieben -> bliebenen
# sang -> sangen
# anpaßte -> anpaßteen
# empfand -> empfanden
# steht -> stehten
# gehörte -> gehörteen
# befragt -> befragten
# Ausgeschlossen -> Ausgeschlossenen
# bringt -> bringten
# ließ -> ließen
# sagte -> sagteen
# riefen -> riefenen
# gelöst -> gelösten
# anließen -> anließenen
# gepackt -> gepackten
# treffen -> treffenen
# hörten -> hörtenen
# schreiben -> schreibenen
# liege -> liegeen
# ausgehalten -> ausgehaltenen
# vereinigen -> vereinigenen
# fortgesetzt -> fortgesetzten
# erlaubte -> erlaubteen
# sah -> sahen
# anwendet -> anwendeten
# übergelegt -> übergelegten
# benutzt -> benutzten
# winken -> winkenen
# vorgemerkt -> vorgemerkten
# versucht -> versuchten
# denken -> denkenen
# haute -> hauteen
# suchen -> suchenen
# klirrte -> klirrteen
# erklärt -> erklärten
# meint -> meinten
# aufgeschlagen -> aufgeschlagenen
# sprechen -> sprechenen
# kehrte -> kehrteen
# erhöht -> erhöhten
# genötigt -> genötigten
# abgeschafft -> abgeschafften
# vorliegt -> vorliegten
# einzugehen -> einzugehenen
# stellt -> stellten
# gegessen -> gegessenen
# legt -> legten
# erwerben -> erwerbenen
# vereinbart -> vereinbarten
# segregieren -> segregierenen
# wünschte -> wünschteen
# unterlassen -> unterlassenen
# gescheitert -> gescheiterten
# verläßt -> verläßten
# läßt -> läßten
# forderte -> forderteen
# mitgemacht -> mitgemachten
# vergessen -> vergessenen
# fürchtete -> fürchteteen
# flattern -> flatteren
# halten -> haltenen
# bewegen -> bewegenen
# verfolgt -> verfolgten
# fraget -> frageten
# gehandelt -> gehandelten
# verstieß -> verstießen
# herfiel -> herfielen
# gelten -> geltenen
# finden -> findenen
# beruft -> beruften
# unterbreitete -> unterbreiteteen
# erhört -> erhörten
# wiederaufnehmen -> wiederaufnehmenen
# wiederbekommt -> wiederbekommten
# aufgehetzt -> aufgehetzten
# gestanden -> gestandenen
# entgegenstehen -> entgegenstehenen
# zusammenbrachte -> zusammenbrachteen
# getrieben -> getriebenen
# gehören -> gehörenen
# bereichern -> bereicheren
# vorbereitet -> vorbereiteten
# schienen -> schienenen
# zugeschrieben -> zugeschriebenen
# verglichen -> verglichenen
# scheint -> scheinten
# behaupteten -> behauptetenen
# versicherte -> versicherteen
# verknüpft -> verknüpften
# herausbringen -> herausbringenen
# tretend -> tretenden
# antworte -> antworteen
# dargestellt -> dargestellten
# zahlte -> zahlteen
# erwecken -> erweckenen
# schrie -> schrieen
# bedeute -> bedeuteen
# bewohnen -> bewohnenen
# ausgegangen -> ausgegangenen
# bleiben -> bleibenen
# erstreckt -> erstreckten
# entstanden -> entstandenen
# Ziehen -> Ziehenen
# litt -> litten
# zugeben -> zugebenen
# beherrschte -> beherrschteen
# pflegt -> pflegten
# erlebt -> erlebten
# gestärkt -> gestärkten
# schnoberte -> schnoberteen
# ersucht -> ersuchten
# aufgegriffen -> aufgegriffenen
# dahingestellt -> dahingestellten
# mitgewaschen -> mitgewaschenen
# fliege -> fliegeen
# treten -> tretenen
# handeln -> handelen
# lasse -> lasseen
# festlegt -> festlegten
# verwirrte -> verwirrteen
# ausgepackt -> ausgepackten
# abstammen -> abstammenen
# anerkannt -> anerkannten
# ansammeln -> ansammelen
# fürchten -> fürchtenen
# erzogen -> erzogenen
# liest -> liesten
# behandelt -> behandelten
# machen -> machenen
# fragte -> fragteen
# tritt -> tritten
# hinkniete -> hinknieteen
# geht -> gehten
# ruckte -> ruckteen
# stellen -> stellenen
# geblinzelt -> geblinzelten
# bezog -> bezogen
# warnen -> warnenen
# niederzuwerfen -> niederzuwerfenen
# verhandelt -> verhandelten
# nimmt -> nimmten
# eintraf -> eintrafen
# hing -> hingen
# getan -> getanen
# stören -> störenen
# reichten -> reichtenen
# einbeziehen -> einbeziehenen
# angesehen -> angesehenen
# herstellend -> herstellenden
# leitet -> leiteten
# stand -> standen
# gesessen -> gesessenen
# einzuhalten -> einzuhaltenen
# leben -> lebenen
# wohnte -> wohnteen
# ginge -> gingeen
# eingelebt -> eingelebten
# empfangen -> empfangenen
# blickte -> blickteen
# abspielen -> abspielenen
# trat -> traten
# abgeben -> abgebenen
# wiederholte -> wiederholteen
# wirtschafteten -> wirtschaftetenen
# beziehen -> beziehenen
# Weiß -> Weißen
# handelt -> handelten
# übertraf -> übertrafen
# sagt -> sagten
# lachte -> lachteen
# gezahlt -> gezahlten
# warf -> warfen
# codiert -> codierten
# verfiel -> verfielen
# klargemacht -> klargemachten
# lief -> liefen
# gucken -> guckenen
# stehenblieben -> stehenbliebenen
# erhebt -> erhebten
# überzeugt -> überzeugten
# nachgehen -> nachgehenen
# ergibt -> ergibten
# geschäumt -> geschäumten
# rechnen -> rechnenen
# balgte -> balgteen
# fanden -> fandenen
# verleiht -> verleihten
# erhielt -> erhielten
# singt -> singten
# hingerichtet -> hingerichteten
# gebrochen -> gebrochenen
# Wiederhol -> Wiederholen
# gezogen -> gezogenen
# geschieht -> geschiehten
# aufgebaut -> aufgebauten
# verabschiedet -> verabschiedeten
# verstummt -> verstummten
# zurückzudrängen -> zurückzudrängenen
# ragt -> ragten
# schläft -> schläften
# verletzt -> verletzten
# antwortete -> antworteteen
# gekannt -> gekannten
# hoben -> hobenen
# anschauen -> anschauenen
# obgewaltet -> obgewalteten
# verstand -> verstanden
# verstehen -> verstehenen
# zensiert -> zensierten
# funktionieren -> funktionierenen
# gestatten -> gestattenen
# verunreinigt -> verunreinigten
# sterben -> sterbenen
# sehe -> seheen
# geölt -> geölten
# tut -> tuten
# heimkommen -> heimkommenen
# kennenzulernen -> kennenzulernenen
# tätet -> täteten
# ordnete -> ordneteen
# erfolgte -> erfolgteen
# gelobt -> gelobten
# genehmigt -> genehmigten
# wendet -> wendeten
# vermeiden -> vermeidenen
# wich -> wichen
# drohend -> drohenden
# schien -> schienen
# stehenbleiben -> stehenbleibenen
# fassen -> fassenen
# herrschte -> herrschteen
# nahmen -> nahmenen
# versetzte -> versetzteen
# saßen -> saßenen
# nehmen -> nehmenen
# abwenden -> abwendenen
# lackiert -> lackierten
# standen -> standenen
# fand -> fanden
# beobachten -> beobachtenen
# lege -> legeen
# aufkommen -> aufkommenen
# veröffentlicht -> veröffentlichten
# winkte -> winkteen
# Geht -> Gehten
# erzeugt -> erzeugten
# auszugehen -> auszugehenen
# spotte -> spotteen
# abgelehnt -> abgelehnten
# warfen -> warfenen
# untersuchen -> untersuchenen
# betrafen -> betrafenen
# plane -> planeen
# aufgegeben -> aufgegebenen
# warteten -> wartetenen
# schlafen -> schlafenen
# hervorschauten -> hervorschautenen
# bestätigt -> bestätigten
# geschworen -> geschworenen
# angerichtet -> angerichteten
# überschätzt -> überschätzten
# sprach -> sprachen
# klingt -> klingten
# auftritt -> auftritten
# übersehen -> übersehenen
# loten -> lotenen
# laufen -> laufenen
# erfordern -> erforderen
# gewöhnt -> gewöhnten
# herausholen -> herausholenen
# kam -> kamen
# nachgesandt -> nachgesandten
# verhört -> verhörten
# blieb -> blieben
# garantiert -> garantierten
# schützt -> schützten
# erschienen -> erschienenen
# sprang -> sprangen
# verhoffe -> verhoffeen
# heißt -> heißten
# besitzen -> besitzenen
# entgegengestellt -> entgegengestellten
# färbt -> färbten
# legten -> legtenen
# verziehen -> verziehenen
# verhaftet -> verhafteten
# bricht -> brichten
# liefert -> lieferten
# erinnert -> erinnerten
# verhindern -> verhinderen
# austreten -> austretenen
# bestritten -> bestrittenen
# sengen -> sengenen
# beschwert -> beschwerten
# legte -> legteen
# erworben -> erworbenen
# erlauben -> erlaubenen
# gedrillt -> gedrillten
# sangen -> sangenen
# merkte -> merkteen
# vorausgesetzt -> vorausgesetzten
# lauerte -> lauerteen
# erteilt -> erteilten
# anzutun -> anzutunen
# drangen -> drangenen
# gestaltete -> gestalteteen
# bringen -> bringenen
# knickten -> knicktenen
# fehlten -> fehltenen
# bestehen -> bestehenen
# fächert -> fächerten
# eingetreten -> eingetretenen
# gesucht -> gesuchten
# bestehe -> besteheen
# beansprucht -> beanspruchten
# mindert -> minderten
# gebilligt -> gebilligten
# fälle -> fälleen
# lebte -> lebteen
# wagte -> wagteen
# abbauen -> abbauenen
# schaffen -> schaffenen
