# %% [markdown]
# # Lemmatisierung mit regulären Ausdrücken ... zumindest fast
# In dieser Übung geht es darum, die Flexionsaffixe von Verben zu entfernen. Dies ist ein erster Schritt zur Lemmatisierung, also dazu, konkrete Wortformen auf ihre Zitierformen im Lexikon zurückzuführen. Wir werden dabei sehen, dass es mit diesem Schritt oft nicht getan ist, dass ordentliche Lemmatisierung also noch ein gutes Stück schwieriger ist.

# %% [markdown]
# ## Nötige Pakete importieren
# Um eine TSV-Datei zu öffnen, verwenden wir hier *pandas*, weil wir damit leichter auf einzelne Tabellenspalten zuzugreifen. Achtung, Pandas ist nicht Teil der Standardbibliothek und muss separat installiert werden. Das sollte in den meisten Python3-Umgebungen über den Python-eigenen Paketmanager `pip3` möglich sein. Um Pandas zu installieren, muss nur der Befehl `pip3 install --user pandas` in einem Terminal ausgeführt werden. (Wer eine Entwicklungsumgebung wie PyCharm nutzt, kann das ggf. auch über ein Menü dieser Umgebung erledigen.)
#
# Sollte die Installation von Pandas nicht möglich sein, kann die TSV-Datei auch über das `csv`-Modul der Standardbibliothek eingelesen werden. Eine Anleitung, wie das möglich ist, gibt es z. B. [hier](https://medium.com/@adds68/parsing-tsv-file-with-csv-in-python-662d6347b0cd).
#
# Außerdem brauchen wir natürlich reguläre Ausdrücke.

# %%
import pandas as pd
import re

# %% [markdown]
# ## Tabelle einlesen
# Die Datei "uebung_verben.tsv" enthält 500 Treffer aus einer Suche nach Vollverben im DWDS-Kernkorpus. (Die Abfrage sieht so aus: <https://www.dwds.de/r?q=%24p%3DVV*+%23sep&corpus=kern&date-start=1900&date-end=1999&genre=Belletristik&genre=Wissenschaft&genre=Gebrauchsliteratur&genre=Zeitung&format=full&sort=random&limit=10>)
#
# Neben den konkreten Wortformen, die von der Abfrage gefunden wurden, enthält die Datei auch für jede Form den kompletten Satz, in dem sie vorkommt, sowie Informationen zur Textquelle. Jede Information befindet sich in einer eigenen Spalte der Tabelle.
#
# Da Spalten in dieser Tabelle mit Tabstops (`\t`) getrennt sind, bietet sich `read_table()` an.

# %%
path = "data/uebung_verben.tsv"
table = pd.read_table(path)
table
# Out:
#           match                                           sentence collection  \
# 0      entsteht  Es bleibt wohl dem , der die Frage zu stellen ...       kern
# 1      verloren  Diese Sumpfreminiszenzen , die mich nicht herg...       kern
# 2    abschaffen  Hitler ist schon seit langen Monaten deutscher...       kern
# 3         hielt  Warum tat er es nicht , sondern hielt an sich ...       kern
# 4      bewahren  Er besitzt eigentlich alles , was eine Frau vo...       kern
# ..          ...                                                ...        ...
# 495       fälle  Und der Satz » ich fälle einen Baum « ist eben...       kern
# 496       lebte  Für mich war der Kreis bedeutsam durch eine st...       kern
# 497       wagte  Bald wagte ein Wärter , sich ihm und der Kiste...       kern
# 498     abbauen  Und wenn die Ausgaben hierfür und für die Wart...       kern
# 499    schaffen  Da man trotz öfteren gegenteiligen Versicherun...       kern
#
#                            author  \
# 0               Sloterdijk, Peter
# 1                       May, Karl
# 2    Kurt Tucholsky:Kaspar Hauser
# 3                   Huch, Ricarda
# 4                   Strauß, Botho
# ..                            ...
# 495               Mauthner, Fritz
# 496               Steiner, Rudolf
# 497             Morgner, Irmtraud
# 498                   Grimm, Hans
# 499                       unknown
#
#                                                  title  \
# 0                        Kritik der zynischen Vernunft
# 1                               Mein Leben und Streben
# 2                                    Hitler und Goethe
# 3                       Der große Krieg in Deutschland
# 4                                       Der junge Mann
# ..                                                 ...
# 495                         Wörterbuch der Philosophie
# 496                                    Mein Lebensgang
# 497  Leben und Abenteuer der Trobadora Beatriz nach...
# 498                                     Volk ohne Raum
# 499                                                NaN
#
#                                textClass  \
# 0                           Wissenschaft
# 1    Gebrauchsliteratur::Autobiographien
# 2                                Zeitung
# 3       Belletristik::Gebrauchsliteratur
# 4                    Belletristik::Roman
# ..                                   ...
# 495             Wissenschaft::Phiosophie
# 496  Gebrauchsliteratur::Autobiographien
# 497                         Belletristik
# 498                  Belletristik::Roman
# 499               Zeitung::Abend-Ausgabe
#
#                                                   bibl        date
# 0    Sloterdijk, Peter: Kritik der zynischen Vernun...  1983-12-31
# 1    May, Karl: Mein Leben und Streben, Selbstbiogr...  1910-12-31
# 2    Tucholsky, Kurt: Hitler und Goethe. In: Kurt T...  1932-05-17
# 3    Huch, Ricarda: Der Dreißigjährige Krieg, Wiesb...  1914-12-31
# 4    Strauß, Botho: Der junge Mann, München: Hanser...  1984-12-31
# ..                                                 ...         ...
# 495  Mauthner, Fritz: Wörterbuch der Philosophie. I...  1910-12-31
# 496  Steiner, Rudolf: Mein Lebensgang, Eine nicht v...  1925-04-05
# 497  Morgner, Irmtraud: Leben und Abenteuer der Tro...  1974-12-31
# 498  Grimm, Hans: Volk ohne Raum, München: Langen 1...  1926-12-31
# 499     Berliner Tageblatt (Abend-Ausgabe), 04.03.1916  1916-03-04
#
# [500 rows x 8 columns]

# %% [markdown]
# ## Verbformen

# %% [markdown]
# Wir brauchen hier eigentlich nur die erste Spalte ...

# %%
verben = table["match"].sort_values()
verben
# Out:
# 185    Ausgeschlossen
# 422              Geht
# 343              Weiß
# 369         Wiederhol
# 280            Ziehen
#             ...
# 89         überreicht
# 438       überschätzt
# 442         übersehen
# 345          übertraf
# 357         überzeugt
# Name: match, Length: 500, dtype: object

# %% [markdown]
# Das ist nun strenggenommen ein spezieller Objekttyp aus *pandas* (nämlich *Series*), aber wir können ganz normal damit arbeiten.
#
# Die Aufgabe besteht nun darin, den untenstehenden Code so anzupassen, dass bei jeder Verbform Flexionsaffixe entfernt werden.  Eine kurze Übersicht über Verbkonjugation im Deutschen gibt es z.B. bei Wikipedia: <https://de.wikipedia.org/wiki/Konjugation_(Grammatik)>
#
# Finde also einen passenden regulären Ausdruck!
#
# Welche Probleme treten dabei auf? Welche weiteren Schritte müssten für eine vollständige Lemmatisierung noch umgesetzt werden?
#
# **Größte verbleibende Probleme: Umlaute und unregelmäßige Formen! Sind nicht vorhersehbar und müssen in einem Lexikon nachgeschlagen werden.**

# %%
infinitives = []
flektionsmuster = [
    r'(\w+)end', # partizip 1
    r'(\w+)ge(\w+)(?:t|en)', # perfekt partikelverb
    r'ge(\w+)(?:t|en)', # perfekt
    r'(\w+[^t])t(?:en|[se]t|[et])', # präteritum
    r'(\w+)(?:en|[se]t|[etd])', # präsens
    r'(\w+[rl])n', # infinitiv
    r'(\w+)' # catch-all
]

# nicht gefordert, aber auch interessant. Stichwort 2-Ebenen-Morphologie.
tilgungen = [
    (r"((?<!i)e[rl])'e", r"\1"),
    (r"e'e", "e"),
    (r"([aeiouäöü])'e", r"\1te"),
    (r"'", "")
]

def lemma(verb):
    for muster in flektionsmuster:
        match = re.fullmatch(muster, verb)

        if match is not None:
            return ''.join(match.groups())

def tilgung(lemma):
    for muster, repl in tilgungen:
        lemma = re.sub(muster, repl, lemma)
    return lemma

for verb in verben:
    zwischen = lemma(verb) + "'en"
    infinitiv = tilgung(zwischen)

    print(f"{verb} -> {zwischen} -> {infinitiv}")
    
    infinitives.append(infinitiv)
# Out:
# Ausgeschlossen -> Ausschloss'en -> Ausschlossen
# Geht -> Geh'en -> Gehen
# Weiß -> Weiß'en -> Weißen
# Wiederhol -> Wiederhol'en -> Wiederholen
# Ziehen -> Zieh'en -> Ziehen
# abbauen -> abbau'en -> abbauten
# abgeben -> abb'en -> abben
# abgegeben -> abgeb'en -> abgeben
# abgelehnt -> ablehn'en -> ablehnen
# abgeschafft -> abschaff'en -> abschaffen
# abgeändert -> abänder'en -> abändern
# ablegte -> ableg'en -> ablegen
# abschaffen -> abschaff'en -> abschaffen
# abschnitten -> abschnitt'en -> abschnitten
# abspielen -> abspiel'en -> abspielen
# abstammen -> abstamm'en -> abstammen
# abwenden -> abwend'en -> abwenden
# anerkannt -> anerkann'en -> anerkannen
# angedeihen -> andeih'en -> andeihen
# angekettet -> ankette'en -> anketten
# angeredet -> anrede'en -> anreden
# angerichtet -> anrichte'en -> anrichten
# angesehen -> anseh'en -> ansehen
# angewachsen -> anwachs'en -> anwachsen
# ankommt -> ankomm'en -> ankommen
# anließen -> anließ'en -> anließen
# anpaßte -> anpaß'en -> anpaßen
# ansammeln -> ansammel'en -> ansammeln
# anschauen -> anschau'en -> anschauten
# antworte -> antwor'en -> antworen
# antwortete -> antworte'en -> antworten
# anvertraut -> anvertrau'en -> anvertrauten
# anwendet -> anwende'en -> anwenden
# anzutun -> anzutun'en -> anzutunen
# arbeitet -> arbei'en -> arbeiten
# aufgebaut -> aufbau'en -> aufbauten
# aufgefordert -> aufforder'en -> auffordern
# aufgeführt -> aufführ'en -> aufführen
# aufgegeben -> aufgeb'en -> aufgeben
# aufgegriffen -> aufgriff'en -> aufgriffen
# aufgehetzt -> aufhetz'en -> aufhetzen
# aufgeschlagen -> aufschlag'en -> aufschlagen
# aufkommen -> aufkomm'en -> aufkommen
# aufschrie -> aufschri'en -> aufschriten
# auftritt -> auftri'en -> auftriten
# aufwies -> aufwies'en -> aufwiesen
# ausgegangen -> ausgang'en -> ausgangen
# ausgehalten -> aushalt'en -> aushalten
# ausgepackt -> auspack'en -> auspacken
# ausgeschlossen -> ausschloss'en -> ausschlossen
# ausgezogen -> auszog'en -> auszogen
# ausschüttete -> ausschütte'en -> ausschütten
# austreten -> austre'en -> austren
# auswirken -> auswirk'en -> auswirken
# auszugehen -> auszuh'en -> auszuhen
# aß -> aß'en -> aßen
# balgte -> balg'en -> balgen
# beansprucht -> beanspruch'en -> beanspruchen
# bearbeitet -> bearbei'en -> bearbeiten
# bedeute -> bedeu'en -> bedeuten
# befragt -> befrag'en -> befragen
# begann -> begann'en -> begannen
# begegneten -> begnet'en -> begneten
# behalten -> behal'en -> behalen
# behandelt -> behandel'en -> behandeln
# behaupteten -> behaupte'en -> behaupten
# beherrschte -> beherrsch'en -> beherrschen
# bekundet -> bekunde'en -> bekunden
# belastet -> belas'en -> belasen
# benutzt -> benutz'en -> benutzen
# beobachten -> beobach'en -> beobachen
# bereichern -> bereicher'en -> bereichern
# beruft -> beruf'en -> berufen
# beschwert -> beschwer'en -> beschwern
# besitzen -> besitz'en -> besitzen
# bestehe -> besteh'en -> bestehen
# bestehen -> besteh'en -> bestehen
# bestritten -> bestritt'en -> bestritten
# bestätigt -> bestätig'en -> bestätigen
# besucht -> besuch'en -> besuchen
# betrafen -> betraf'en -> betrafen
# betrifft -> betriff'en -> betriffen
# bewahren -> bewahr'en -> bewahren
# bewegen -> beweg'en -> bewegen
# bewegte -> beweg'en -> bewegen
# bewilligt -> bewillig'en -> bewilligen
# bewohnen -> bewohn'en -> bewohnen
# beziehen -> bezieh'en -> beziehen
# bezog -> bezog'en -> bezogen
# bleiben -> bleib'en -> bleiben
# blickte -> blick'en -> blicken
# blieb -> blieb'en -> blieben
# blieben -> blieb'en -> blieben
# brauchen -> brauch'en -> brauchen
# bricht -> brich'en -> brichen
# bringen -> bring'en -> bringen
# bringt -> bring'en -> bringen
# codiert -> codier'en -> codieren
# dahingestellt -> dahinstell'en -> dahinstellen
# dargestellt -> darstell'en -> darstellen
# darstellt -> darstell'en -> darstellen
# denken -> denk'en -> denken
# diskutieren -> diskutier'en -> diskutieren
# drangen -> drang'en -> drangen
# drehen -> dreh'en -> drehen
# drohend -> droh'en -> drohen
# durcheilt -> durcheil'en -> durcheilen
# einbeziehen -> einbezieh'en -> einbeziehen
# einbringe -> einbring'en -> einbringen
# eingeht -> einh'en -> einhen
# eingelebt -> einleb'en -> einleben
# eingetreten -> eintret'en -> eintreten
# eingetroffen -> eintroff'en -> eintroffen
# eintraf -> eintraf'en -> eintrafen
# einzugehen -> einzuh'en -> einzuhen
# einzuhalten -> einzuhal'en -> einzuhalen
# empfand -> empfan'en -> empfanen
# empfangen -> empfang'en -> empfangen
# entgegengestellt -> entgegenstell'en -> entgegenstellen
# entgegenstehen -> entgensteh'en -> entgenstehen
# enthält -> enthäl'en -> enthälen
# entstanden -> entstand'en -> entstanden
# entsteht -> entsteh'en -> entstehen
# erfolgt -> erfolg'en -> erfolgen
# erfolgte -> erfolg'en -> erfolgen
# erfordern -> erforder'en -> erfordern
# ergibt -> ergib'en -> ergiben
# erhebt -> erheb'en -> erheben
# erhielt -> erhiel'en -> erhielen
# erhob -> erhob'en -> erhoben
# erhöht -> erhöh'en -> erhöhen
# erhört -> erhör'en -> erhören
# erinnert -> erinner'en -> erinnern
# erkennen -> erkenn'en -> erkennen
# erklären -> erklär'en -> erklären
# erklärt -> erklär'en -> erklären
# erlauben -> erlaub'en -> erlauben
# erlaubte -> erlaub'en -> erlauben
# erlebt -> erleb'en -> erleben
# erregt -> erreg'en -> erregen
# erschienen -> erschien'en -> erschienen
# erstreckt -> erstreck'en -> erstrecken
# ersucht -> ersuch'en -> ersuchen
# erteilt -> erteil'en -> erteilen
# erwecken -> erweck'en -> erwecken
# erwerben -> erwerb'en -> erwerben
# erwiderte -> erwider'en -> erwidern
# erworben -> erworb'en -> erworben
# erzeugt -> erzeug'en -> erzeugen
# erzogen -> erzog'en -> erzogen
# erörtern -> erörter'en -> erörtern
# fand -> fan'en -> fanen
# fanden -> fand'en -> fanden
# fassen -> fass'en -> fassen
# fehlten -> fehl'en -> fehlen
# festlegt -> festleg'en -> festlegen
# festzusetzen -> festzusetz'en -> festzusetzen
# finden -> find'en -> finden
# findet -> finde'en -> finden
# flattern -> flatter'en -> flattern
# fliege -> flieg'en -> fliegen
# folgt -> folg'en -> folgen
# folgte -> folg'en -> folgen
# fordern -> forder'en -> fordern
# forderte -> forder'en -> fordern
# formuliert -> formulier'en -> formulieren
# fortgesetzt -> fortsetz'en -> fortsetzen
# fraget -> frage'en -> fragen
# fragte -> frag'en -> fragen
# funktionieren -> funktionier'en -> funktionieren
# fächert -> fächer'en -> fächern
# fälle -> fäll'en -> fällen
# fällt -> fäll'en -> fällen
# färbt -> färb'en -> färben
# führen -> führ'en -> führen
# führt -> führ'en -> führen
# fürchten -> fürch'en -> fürchen
# fürchtete -> fürchte'en -> fürchten
# gab -> gab'en -> gaben
# garantieren -> garantier'en -> garantieren
# garantiert -> garantier'en -> garantieren
# geben -> b'en -> ben
# gebilligt -> billig'en -> billigen
# geblinzelt -> blinzel'en -> blinzeln
# geboren -> bor'en -> boren
# gebrochen -> broch'en -> brochen
# gedachte -> gedach'en -> gedachen
# gedrillt -> drill'en -> drillen
# geführt -> führ'en -> führen
# gegenüberzusetzen -> genüberzusetz'en -> genüberzusetzen
# gegessen -> gess'en -> gessen
# gegründet -> gründe'en -> gründen
# gehandelt -> handel'en -> handeln
# gehangen -> hang'en -> hangen
# gehen -> h'en -> hen
# geholfen -> holf'en -> holfen
# geht -> h'en -> hen
# gehören -> hör'en -> hören
# gehört -> hör'en -> hören
# gehörte -> gehör'en -> gehören
# geißelte -> geißel'en -> geißeln
# gekannt -> kann'en -> kannen
# gekommen -> komm'en -> kommen
# gekriegt -> krieg'en -> kriegen
# gelautet -> laute'en -> lauten
# gellt -> ll'en -> llen
# gelobt -> lob'en -> loben
# gelten -> lt'en -> lten
# gelöst -> lös'en -> lösen
# gemacht -> mach'en -> machen
# genannt -> nann'en -> nannen
# genehmigt -> nehmig'en -> nehmigen
# genommen -> nomm'en -> nommen
# genötigt -> nötig'en -> nötigen
# gepackt -> pack'en -> packen
# gepflückt -> pflück'en -> pflücken
# geraucht -> rauch'en -> rauchen
# gerichtet -> richte'en -> richten
# gerührt -> rühr'en -> rühren
# gesagt -> sag'en -> sagen
# gesandt -> sand'en -> sanden
# gescheitert -> scheiter'en -> scheitern
# geschieht -> schieh'en -> schiehen
# geschminkt -> schmink'en -> schminken
# geschworen -> schwor'en -> schworen
# geschäumt -> schäum'en -> schäumen
# gesehen -> seh'en -> sehen
# gesehn -> gesehn'en -> gesehnen
# gesessen -> sess'en -> sessen
# gespuckt -> spuck'en -> spucken
# gestaltete -> gestalte'en -> gestalten
# gestanden -> stand'en -> standen
# gestatten -> statt'en -> statten
# gestattet -> statte'en -> statten
# gestopft -> stopf'en -> stopfen
# gestorben -> storb'en -> storben
# gestärkt -> stärk'en -> stärken
# gesucht -> such'en -> suchen
# getan -> getan'en -> getanen
# getrieben -> trieb'en -> trieben
# gewählt -> wähl'en -> wählen
# gewöhnt -> wöhn'en -> wöhnen
# gezahlt -> zahl'en -> zahlen
# gezogen -> zog'en -> zogen
# geölt -> öl'en -> ölen
# gibt -> gib'en -> giben
# ging -> ging'en -> gingen
# ginge -> ging'en -> gingen
# griff -> griff'en -> griffen
# gucken -> guck'en -> gucken
# halten -> hal'en -> halen
# handeln -> handel'en -> handeln
# handelt -> handel'en -> handeln
# haute -> hau'en -> hauten
# heimkommen -> heimkomm'en -> heimkommen
# heiraten -> heira'en -> heiraten
# heißt -> heiß'en -> heißen
# herausbringen -> herausbring'en -> herausbringen
# herausholen -> heraushol'en -> herausholen
# herbeiführen -> herbeiführ'en -> herbeiführen
# herfiel -> herfiel'en -> herfielen
# herrschte -> herrsch'en -> herrschen
# herstellend -> herstell'en -> herstellen
# hervorschauten -> hervorschau'en -> hervorschauten
# hielt -> hiel'en -> hielen
# hing -> hing'en -> hingen
# hingerichtet -> hinrichte'en -> hinrichten
# hinkniete -> hinknie'en -> hinknien
# hoben -> hob'en -> hoben
# hören -> hör'en -> hören
# hörte -> hör'en -> hören
# hörten -> hör'en -> hören
# kam -> kam'en -> kamen
# kehrte -> kehr'en -> kehren
# kennenzulernen -> kennenzulern'en -> kennenzulernen
# klargemacht -> klarmach'en -> klarmachen
# klingt -> kling'en -> klingen
# klirrte -> klirr'en -> klirren
# knickten -> knick'en -> knicken
# kommen -> komm'en -> kommen
# kommt -> komm'en -> kommen
# konferierte -> konferier'en -> konferieren
# kostete -> koste'en -> kosten
# krallte -> krall'en -> krallen
# kämpfen -> kämpf'en -> kämpfen
# lachte -> lach'en -> lachen
# lackiert -> lackier'en -> lackieren
# lasse -> lass'en -> lassen
# lassen -> lass'en -> lassen
# lauerte -> lauer'en -> lauern
# laufen -> lauf'en -> laufen
# leben -> leb'en -> leben
# lebte -> leb'en -> leben
# lege -> leg'en -> legen
# legt -> leg'en -> legen
# legte -> leg'en -> legen
# legten -> leg'en -> legen
# leitet -> lei'en -> leiten
# lief -> lief'en -> liefen
# liefern -> liefer'en -> liefern
# liefert -> liefer'en -> liefern
# liege -> lieg'en -> liegen
# liegt -> lieg'en -> liegen
# liest -> lies'en -> liesen
# ließ -> ließ'en -> ließen
# litt -> li'en -> liten
# loten -> lo'en -> loten
# läßt -> läß'en -> läßen
# machen -> mach'en -> machen
# macht -> mach'en -> machen
# machte -> mach'en -> machen
# meine -> mein'en -> meinen
# meint -> mein'en -> meinen
# meldet -> melde'en -> melden
# merken -> merk'en -> merken
# merkte -> merk'en -> merken
# mindert -> minder'en -> mindern
# mitgemacht -> mitmach'en -> mitmachen
# mitgewaschen -> mitwasch'en -> mitwaschen
# nachgehen -> nachh'en -> nachhen
# nachgesandt -> nachsand'en -> nachsanden
# nahm -> nahm'en -> nahmen
# nahmen -> nahm'en -> nahmen
# nehmen -> nehm'en -> nehmen
# nennen -> nenn'en -> nennen
# niederzuwerfen -> niederzuwerf'en -> niederzuwerfen
# nimmt -> nimm'en -> nimmen
# notiert -> notier'en -> notieren
# obgewaltet -> obwalte'en -> obwalten
# ordnete -> ordne'en -> ordnen
# paßt -> paß'en -> paßen
# paßte -> paß'en -> paßen
# pflegt -> pfleg'en -> pflegen
# plane -> plan'en -> planen
# polierten -> polier'en -> polieren
# ragt -> rag'en -> ragen
# rechnen -> rechn'en -> rechnen
# reduziert -> reduzier'en -> reduzieren
# regnete -> regne'en -> regnen
# reichten -> reich'en -> reichen
# riechen -> riech'en -> riechen
# rief -> rief'en -> riefen
# riefen -> rief'en -> riefen
# ruckte -> ruck'en -> rucken
# sagen -> sag'en -> sagen
# sagt -> sag'en -> sagen
# sagte -> sag'en -> sagen
# sah -> sah'en -> sahen
# sang -> sang'en -> sangen
# sangen -> sang'en -> sangen
# saßen -> saß'en -> saßen
# schaffen -> schaff'en -> schaffen
# scheint -> schein'en -> scheinen
# schien -> schi'en -> schiten
# schienen -> schien'en -> schienen
# schimpfen -> schimpf'en -> schimpfen
# schlafen -> schlaf'en -> schlafen
# schläft -> schläf'en -> schläfen
# schnoberte -> schnober'en -> schnobern
# schreiben -> schreib'en -> schreiben
# schrie -> schri'en -> schriten
# schwieg -> schwieg'en -> schwiegen
# schützt -> schütz'en -> schützen
# segregieren -> segregier'en -> segregieren
# sehe -> seh'en -> sehen
# sehen -> seh'en -> sehen
# sengen -> seng'en -> sengen
# setzen -> setz'en -> setzen
# siedelte -> siedel'en -> siedeln
# sieht -> sieh'en -> siehen
# singt -> sing'en -> singen
# sitzen -> sitz'en -> sitzen
# spotte -> spott'en -> spotten
# sprach -> sprach'en -> sprachen
# sprang -> sprang'en -> sprangen
# sprechen -> sprech'en -> sprechen
# stand -> stan'en -> stanen
# standen -> stand'en -> standen
# stehenbleiben -> stehenbleib'en -> stehenbleiben
# stehenblieben -> stehenblieb'en -> stehenblieben
# steht -> steh'en -> stehen
# steigern -> steiger'en -> steigern
# stellen -> stell'en -> stellen
# stellt -> stell'en -> stellen
# sterben -> sterb'en -> sterben
# stimme -> stimm'en -> stimmen
# stoben -> stob'en -> stoben
# sträubte -> sträub'en -> sträuben
# stören -> stör'en -> stören
# suchen -> such'en -> suchen
# tagte -> tag'en -> tagen
# teilnimmt -> teilnimm'en -> teilnimmen
# trat -> tra'en -> traten
# treffen -> treff'en -> treffen
# trennen -> trenn'en -> trennen
# treten -> tre'en -> tren
# tretend -> tret'en -> treten
# tritt -> tri'en -> triten
# träumend -> träum'en -> träumen
# tut -> tu'en -> tuten
# tätet -> tä'en -> täten
# umfaßte -> umfaß'en -> umfaßen
# unterbreitete -> unterbreite'en -> unterbreiten
# unterlassen -> unterlass'en -> unterlassen
# unterliegen -> unterlieg'en -> unterliegen
# untersuchen -> untersuch'en -> untersuchen
# unterzeichnen -> unterzeichn'en -> unterzeichnen
# verabschiedet -> verabschiede'en -> verabschieden
# vereinbart -> vereinbar'en -> vereinbaren
# vereinigen -> vereinig'en -> vereinigen
# verfiel -> verfiel'en -> verfielen
# verfolgen -> verfolg'en -> verfolgen
# verfolgt -> verfolg'en -> verfolgen
# vergessen -> verss'en -> verssen
# verglichen -> verglich'en -> verglichen
# verhaftet -> verhaf'en -> verhafen
# verhandelt -> verhandel'en -> verhandeln
# verheißt -> verheiß'en -> verheißen
# verhindern -> verhinder'en -> verhindern
# verhindert -> verhinder'en -> verhindern
# verhoffe -> verhoff'en -> verhoffen
# verhört -> verhör'en -> verhören
# verknüpft -> verknüpf'en -> verknüpfen
# verkündet -> verkünde'en -> verkünden
# verkündete -> verkünde'en -> verkünden
# verlangen -> verlang'en -> verlangen
# verlassen -> verlass'en -> verlassen
# verleiht -> verleih'en -> verleihen
# verletzt -> verletz'en -> verletzen
# verloren -> verlor'en -> verloren
# verläßt -> verläß'en -> verläßen
# vermeiden -> vermeid'en -> vermeiden
# verringern -> verringer'en -> verringern
# verschwand -> verschwan'en -> verschwanen
# versetzte -> versetz'en -> versetzen
# versicherte -> versicher'en -> versichern
# verstand -> verstan'en -> verstanen
# verstehen -> versteh'en -> verstehen
# verstieß -> verstieß'en -> verstießen
# verstummt -> verstumm'en -> verstummen
# versuchen -> versuch'en -> versuchen
# versucht -> versuch'en -> versuchen
# verunreinigt -> verunreinig'en -> verunreinigen
# verwirrte -> verwirr'en -> verwirren
# verzichten -> verzich'en -> verzichen
# verziehen -> verzieh'en -> verziehen
# veröffentlichen -> veröffentlich'en -> veröffentlichen
# veröffentlicht -> veröffentlich'en -> veröffentlichen
# vollud -> vollu'en -> volluten
# vorausgesetzt -> voraussetz'en -> voraussetzen
# voraussehen -> vorausseh'en -> voraussehen
# vorbeigefahren -> vorbeifahr'en -> vorbeifahren
# vorbereitet -> vorberei'en -> vorbereiten
# vorgemerkt -> vormerk'en -> vormerken
# vorliegt -> vorlieg'en -> vorliegen
# wagte -> wag'en -> wagen
# wandeln -> wandel'en -> wandeln
# warf -> warf'en -> warfen
# warfen -> warf'en -> warfen
# warnen -> warn'en -> warnen
# warteten -> warte'en -> warten
# wechselte -> wechsel'en -> wechseln
# weiß -> weiß'en -> weißen
# wende -> wend'en -> wenden
# wendet -> wende'en -> wenden
# wich -> wich'en -> wichen
# wiederaufnehmen -> wiederaufnehm'en -> wiederaufnehmen
# wiederbekommt -> wiederbekomm'en -> wiederbekommen
# wiederholte -> wiederhol'en -> wiederholen
# winken -> wink'en -> winken
# winkte -> wink'en -> winken
# wirft -> wirf'en -> wirfen
# wirken -> wirk'en -> wirken
# wirtschafteten -> wirtschafte'en -> wirtschaften
# wohnt -> wohn'en -> wohnen
# wohnte -> wohn'en -> wohnen
# wähle -> wähl'en -> wählen
# wünschte -> wünsch'en -> wünschen
# zahlte -> zahl'en -> zahlen
# zeichnet -> zeichne'en -> zeichnen
# zeigt -> zeig'en -> zeigen
# zensiert -> zensier'en -> zensieren
# ziehen -> zieh'en -> ziehen
# zieht -> zieh'en -> ziehen
# zugeben -> zub'en -> zuben
# zugelassen -> zulass'en -> zulassen
# zugeschrieben -> zuschrieb'en -> zuschrieben
# zurückkommen -> zurückkomm'en -> zurückkommen
# zurückzudrängen -> zurückzudräng'en -> zurückzudrängen
# zusammenbrachte -> zusammenbrach'en -> zusammenbrachen
# zusammengenommen -> zusammennomm'en -> zusammennommen
# zählt -> zähl'en -> zählen
# überführen -> überführ'en -> überführen
# übergelegt -> überleg'en -> überlegen
# übergesetzt -> übersetz'en -> übersetzen
# überreicht -> überreich'en -> überreichen
# überschätzt -> überschätz'en -> überschätzen
# übersehen -> überseh'en -> übersehen
# übertraf -> übertraf'en -> übertrafen
# überzeugt -> überzeug'en -> überzeugen

# %% [markdown]
# ### Evaluation
# Die folgende Methode überprüft, wie hoch der Anteil der korrekt lemmatisierten Worte ist. Evaluiere gerne einmal deine Lösung und versuche ein von Dir gestecktes Ziel, wie etwa 65% korrekter Lemmata, zu erreichen.

# %%
def evaluate(infinitives, method='accuracy'):
    """Evaluate the accuracy of a list of infinitives against their lemma.

    Parameters
    ----------
    infinitives : iterable of str
        The infinitives to be evaluated.
    method : {'accuracy', 'positives', 'negatives'}
        Wether to return only the accuracy of lemmatisation or 
        additionally print either all correct or incorrect infinitives to 
        the console.
        
    Returns
    -------
    float
        The percentage of correctly lemmatised infinitives.

    """
    def compare_pair(word1, word2, method):
        if word1 == word2:
            if method == 'positives':
                print(word1)
            return 1
        
        elif method == 'negatives':
            print(word1, word2)

        return 0
        
    correct = 0
    total = 0
    
    with open('data/uebung_verben_lemmata.txt', encoding='utf-8') as lemmata:
        for result, lemma in zip(infinitives, lemmata):
            total += 1
            correct += compare_pair(result, lemma.rstrip(), method)
        
    return correct / total

# %%
evaluate(infinitives)
# Out:
# 0.674
